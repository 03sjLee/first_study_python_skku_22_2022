# %%
import random

def Check_Num(n1):
    
    global success_num
    
    if n1 > success_num:
        print("DOWN")
    elif n1 < success_num:
        print("UP")
    else:
        print("SUCCESS")
        return "S"
    


success_num = random.randrange(1, 100)

print("Game Start!")

while True :                       # while success_num != n
    n = int(input("n: "))
    
    aa = Check_Num(n)
    
    if(aa == "S"):
        break
# Out:
# Game Start!
# n: 5
# UP
# n: 10
# UP
# n: 50
# UP
# n: 60
# UP
# n: 70
# DOWN
# n: 65
# DOWN
# n: 64
# DOWN
# n: 63
# DOWN
# n: 62
# DOWN
# n: 61
# SUCCESS

# %%
import random

def Check_Num(n1,n2,n3):
    global num1
    global num2
    global num3
    
    check = (n1,n2,n3)
    tmp = (num1,num2,num3)
    
    strike_point = 0
    ball_point = 0
    
    for i in range(3):
        if check[i]==tmp[i]:
            strike_point += 1
    
    if n1 == num2 or n1 == num3:
        ball_point += 1
    
    if n2 == num1 or n2 == num3:
        ball_point += 1

    if n3 == num1 or n3 == num2:
        ball_point += 1
        
    return strike_point, ball_point
    
    
            
def Check_win(a):
    if a <= 9:
        print("USER WIN!")
    else :
        print("COMPUTER WIN!")
    
    

while True:

    first = input("Play game? (y,n): ")
    
    if first == "n":
        break
  
    num1 = random.randrange(0, 10)
    num2 = random.randrange(0, 10)
    num3 = random.randrange(0, 10)
    
    while not (num1 == num2 or num1 == num3 or num2 == num3):
    
        num1 = random.randrange(0, 10)
        num2 = random.randrange(0, 10)
        num3 = random.randrange(0, 10)     
    
    Round = 0 
    
    while True:
        
        Round += 1
        print(f"*** BaseBall Game....Round : {Round}")
        
    
        N1 = int(input("1st number: "))
        N2 = int(input("2nd number: "))
        N3 = int(input("3rd number: "))
    
        SK,BA = Check_Num(N1,N2,N3)
            
        if SK<3 and SK>0 :
            print(f"{SK} STRIKE! ", end="")
        
        elif SK==3 :
            print(f"{SK} STRIKE!")
            break
            
        else :
            pass
        
        if BA == 0 :
            print("OUT!")
        else :
            print(f"{BA} BALL!")    
        
        
    Check_win(Round)
# Out:
# Play game? (y,n): y
# *** BaseBall Game....Round : 1
# 1st number: 1
# 2nd number: 2
# 3rd number: 3
# 2 BALL!
# *** BaseBall Game....Round : 2
# 1st number: 1
# 2nd number: 3
# 3rd number: 4
# 1 STRIKE! 2 BALL!
# *** BaseBall Game....Round : 3
# 1st number: 2
# 2nd number: 3
# 3rd number: 4
# 1 STRIKE! 1 BALL!
# *** BaseBall Game....Round : 4
# 1st number: 1
# 2nd number: 3
# 3rd number: 4
# 1 STRIKE! 2 BALL!
# *** BaseBall Game....Round : 5
# 1st number: 1
# 2nd number: 3
# 3rd number: 5
# 1 STRIKE! 2 BALL!
# *** BaseBall Game....Round : 6
# 1st number: 3
# 2nd number: 1
# 3rd number: 5
# 1 STRIKE! 2 BALL!
# *** BaseBall Game....Round : 7
# 1st number: 5
# 2nd number: 3
# 3rd number: 1
# 2 STRIKE! 1 BALL!
# *** BaseBall Game....Round : 8
